# %%
import pandas as pd

# %%
df = pd.read_csv('../data/ratings.csv')
print(df.shape)
.head(5)
# Out:
# (5976479, 3)
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
df_exbook = pd.read_csv('../data/exclude_books.csv')
print(df_exbook.shape)
df_exbook.tail(5)
# Out:
# (4236, 1)
#       book_id
# 4231     9994
# 4232     9996
# 4233     9997
# 4234     9999
# 4235    10000

# %%
dfbookindex = df.set_index('book_id')
dfbookindex
# Out:
#          user_id  rating
# book_id
# 258            1       5
# 4081           2       4
# 260            2       5
# 9296           2       5
# 2318           2       3
# 26             2       4
# 315            2       3
# 33             2       4
# 301            2       5
# 2686           2       5
# 3753           2       5
# 8519           2       5
# 70             4       4
# 264            4       3
# 388            4       4
# 18             4       5
# 27             4       5
# 21             4       5
# 2              4       5
# 23             4       5
# 24             4       5
# 964            4       4
# 103            4       5
# 255            4       2
# 35             4       5
# 287            4       3
# 337            4       4
# 26             4       3
# 84             4       4
# 58             4       4
# ...          ...     ...
# 5609       49802       3
# 5684       49802       3
# 6080       49802       3
# 7600       49802       3
# ...

# %%
dfbookindex.loc[df_exbook['book_id']] # to drop
# Out:
#          user_id  rating
# book_id
# 45             4       4
# 45             8       3
# 45            22       5
# 45            76       4
# 45            85       4
# 45            89       4
# 45            26       4
# 45           103       5
# 45           108       4
# 45           123       4
# 45           125       4
# 45           126       4
# 45           143       3
# 45           142       3
# 45           149       3
# 45           169       5
# 45           168       5
# 45           195       4
# 45            10       5
# 45           223       4
# 45           219       3
# 45           228       4
# 45           237       5
# 45           206       3
# 45           137       5
# 45           247       4
# 45           263       5
# 45           179       4
# 45           278       4
# 45           303       4
# ...          ...     ...
# 10000      43318       4
# 10000      30136       2
# 10000      43744       4
# 10000      44206       4
# ...

# %%
df_exbook = df_exbook.set_index('book_id')
df_exbook.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [45, 48, 61, 84, 123]

# %%
dfclean = dfbookindex.drop(df_exbook.index)
dfclean
# Out:
#          user_id  rating
# book_id
# 258            1       5
# 4081           2       4
# 260            2       5
# 9296           2       5
# 2318           2       3
# 26             2       4
# 315            2       3
# 33             2       4
# 301            2       5
# 8519           2       5
# 70             4       4
# 264            4       3
# 388            4       4
# 18             4       5
# 27             4       5
# 21             4       5
# 2              4       5
# 23             4       5
# 24             4       5
# 964            4       4
# 103            4       5
# 255            4       2
# 35             4       5
# 287            4       3
# 337            4       4
# 26             4       3
# 58             4       4
# 1117           4       3
# 660            4       3
# 111            4       2
# ...          ...     ...
# 2605       49802       2
# 2911       49802       4
# 3510       49802       4
# 3608       49802       4
# ...

# %%
dfclean = dfclean.reset_index()
dfclean = dfclean.set_index('user_id')
dfclean = dfclean.sort_index()
dfclean = dfclean.reset_index()
dfclean
# Out:
#          user_id  book_id  rating
# 0              1      258       5
# 1              1      109       3
# 2              1      131       4
# 3              1      102       5
# 4              1       95       4
# 5              1      225       4
# 6              1       76       3
# 7              1      100       4
# 8              1      171       3
# 9              1      177       5
# 10             1      179       2
# 11             1      485       4
# 12             1      325       3
# 13             1      498       4
# 14             1      323       3
# 15             1      162       4
# 16             1       72       3
# 17             1      233       4
# 18             1      496       3
# 19             1      255       1
# 20             1      219       4
# 21             1       85       3
# 22             1       54       3
# 23             1       46       4
# 24             1       22       3
# 25             1      115       3
# ...

# %%
dfclean.to_csv('../data/cleaned_ratings.csv')

# %%
dfclean.loc[dfclean['book_id'] == 8014].head() # try find removed books
# Out:
# Empty DataFrame
# Columns: [user_id, book_id, rating]
# Index: []

# %%
# df_cleaned2 = df_cleaned2.drop(df_cleaned2.index[df_exbook['book_id']])
# print(df_cleaned2.shape)
# df_cleaned2
# Out:
# (3421894, 2)
#          user_id  rating
# book_id
# 9296           2       5
# 2318           2       3
# 2686           2       5
# 8519           2       5
# 964            4       4
# 6351           6       4
# 1237           4       5
# 222            4       4
# 5556           1       3
# 1296           4       3
# 596            4       3
# 397            9       3
# 4815           9       5
# 1221           9       3
# 1301           9       2
# 1986           9       2
# 963            9       2
# 596            9       2
# 7868           9       2
# 1407           9       2
# 2559          11       5
# 6944          11       3
# 3560          11       5
# 2903          15       4
# 167           15       5
# 465           15       4
# 8440          15       4
# 4043          15       4
# 9363          15       4
# 8842          15       3
# ...          ...     ...
# 3510       49802       4
# 3832       49802       4
# 3874       49802       5
# 3990       49802       3
# ...
